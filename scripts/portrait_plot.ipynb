# %%
import numpy as np
import pandas as pd
import json
import panel as pn
from matplotlib import pyplot as plt
import holoviews as hv
import hvplot.pandas
from PIL import Image
import os, os.path
from bokeh.models import HoverTool, ColorBar, LinearColorMapper, LogColorMapper, Label
from bokeh.plotting import figure
from bokeh.layouts import row
import os

# %%
os.chdir('/Users/chang61/Documents/PCMDI/peak_season_cmec')

# %%
# load data from json file
f = 'data/peak_season_cmec.json'
with open(f) as og_file:
    dat = json.load(og_file)

# %%
dat

# %%
# convert json data to pandas dataframe 
ps_df = pd.DataFrame.from_dict(dat['RESULTS'], orient='index')

# format pandas df for portrait plot
ps_df['Model'] = ps_df.index
ps_df = ps_df.reset_index()
ps_df = ps_df[['Model', 'peak season']]
ps_df['var_name'] = 'peak season'
ps_df['region_name'] = 'region 1'
ps_df

# %%
# load histogram png files
imgs = []
path = "./images/"
for p in os.listdir(path):
    ext = os.path.splitext(p)[1]
    imgs.append(Image.open(os.path.join(path,p)))

# view one image to confirm
#imgs[0].show()

# %%
# add image links to df
# edit hyperlinks from github repo to match format below (add 'raw.githubusercontent.com', remove 'blob' from path)
# link order should match order of models displayed in df above

img_links = ['https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/BCC-CSM2-MR.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/CSIRO-Mk3.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/CanESM2.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/ERA5.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/MERRA2.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/MRI-ESM2.png',
             'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/NorESM1.png', 
             ]

ps_df['img'] = img_links

# adjust pandas settings to view full column width
pd.set_option('max_colwidth', 1000)

ps_df

# %%
# html for custom hover tool
hover = HoverTool(tooltips="""
    <div>
        <div>
            <img src="@img" width=400 style="float: left; margin: 0px 15px 15px 0px; border="2"></img>
        </div>
    </div>

""")

# %%
peak_plot01 = ps_df.hvplot.heatmap(y='var_name',
                       x='Model',
                       C='peak season',
                       hover_cols = ['img'],
                       tools = [hover],
                       height = 300,
                       width=950,
                       colorbar=True,
                       xaxis='top',
                       cmap='bwr').opts(xrotation=45, fontsize={
                           'labels': 14,
                           'xticks': 14,
                           'yticks': 14
                       })
peak_plot01

# %%
# save portrait plot to charts folder as an html file
# change file name each time saving a new version
# update index.md file to match new html file name

#hvplot.save(peak_plot01, 'charts/peak_plot10.html')

# push changes to github to see updates on live webpage

# %%
# creating reanalyses portrait plot
peak = np.loadtxt('data/output_peak_reanalysis_full.txt')
angle = peak.reshape(3,-1)

# %%
angle = np.where(angle < -182, angle+365, angle)
angle = np.where(angle >  182, angle-365, angle)

print(angle)
# Out:
# [[   7.   63.  -22. -102.  145.  155.    5.   56.  -68. -106.  138.  165.]
#  [   5.   75.  -40. -102.  166.  151.  -56.   -9.   14.  -91.  -89.   14.]
#  [ -49.  -11.   15.  -92.  -92.   15.  -64.  -13.   10.  -63.  -61.  -52.]]

# %%
model_names = ['ERA5','MERRA2','JRA55C']
region_names = ['California','SAmerica', 'Africa','NEurope','Australia','SAfrica', 'Baja', 'PAC NW', 'New Zealand', 'Alaska', 'UK', 'WEurope']

da = pd.DataFrame(data=angle, index=model_names, columns=region_names)

dd = da.stack()
dd = dd.reset_index()
dd = dd.rename(columns={"level_0": "model", "level_1": "region", 0 :"peak"})
ddd = dd['peak'].values

#print(dd)

img_path = 'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/'
img_links = []

for i, model in enumerate(model_names):
    for j, region in enumerate(region_names):
        filename = img_path+'fig_re_'+str(i)+"_"+str(j)+'.png'
        img_links.append(filename)

# %%
dd['img'] = img_links

#print(dd)

# adjust pandas settings to view full column width
pd.set_option('max_colwidth', 1000)

# %%
dd
# Out:
#      model       region   peak  \
# 0     ERA5   California    7.0
# 1     ERA5     SAmerica   63.0
# 2     ERA5       Africa  -22.0
# 3     ERA5      NEurope -102.0
# 4     ERA5    Australia  145.0
# 5     ERA5      SAfrica  155.0
# 6     ERA5         Baja    5.0
# 7     ERA5       PAC NW   56.0
# 8     ERA5  New Zealand  -68.0
# 9     ERA5       Alaska -106.0
# 10    ERA5           UK  138.0
# 11    ERA5      WEurope  165.0
# 12  MERRA2   California    5.0
# 13  MERRA2     SAmerica   75.0
# 14  MERRA2       Africa  -40.0
# 15  MERRA2      NEurope -102.0
# 16  MERRA2    Australia  166.0
# 17  MERRA2      SAfrica  151.0
# 18  MERRA2         Baja  -56.0
# 19  MERRA2       PAC NW   -9.0
# 20  MERRA2  New Zealand   14.0
# 21  MERRA2       Alaska  -91.0
# 22  MERRA2           UK  -89.0
# 23  MERRA2      WEurope   14.0
# 24  JRA55C   California  -49.0
# 25  JRA55C     SAmerica  -11.0
# 26  JRA55C       Africa   15.0
# 27  JRA55C      NEurope  -92.0
# 28  JRA55C    Australia  -92.0
# 29  JRA55C      SAfrica   15.0
# 30  JRA55C         Baja  -64.0
# 31  JRA55C       PAC NW  -13.0
# 32  JRA55C  New Zealand   10.0
# 33  JRA55C       Alaska  -63.0
# 34  JRA55C           UK  -61.0
# 35  JRA55C      WEurope  -52.0
#
#                                                                                              img
# 0    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_0.png
# 1    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_1.png
# 2    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_2.png
# 3    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_3.png
# 4    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_4.png
# 5    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_5.png
# 6    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_6.png
# 7    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_7.png
# 8    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_8.png
# 9    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_9.png
# 10  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_10.png
# 11  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_0_11.png
# 12   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_0.png
# 13   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_1.png
# 14   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_2.png
# 15   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_3.png
# 16   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_4.png
# 17   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_5.png
# 18   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_6.png
# 19   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_7.png
# 20   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_8.png
# 21   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_9.png
# 22  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_10.png
# 23  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_1_11.png
# 24   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_0.png
# 25   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_1.png
# 26   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_2.png
# 27   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_3.png
# 28   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_4.png
# 29   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_5.png
# 30   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_6.png
# 31   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_7.png
# 32   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_8.png
# 33   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_9.png
# 34  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_10.png
# 35  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_re_2_11.png

# %%
hover = HoverTool(tooltips="""
    <div>
        <div>
            <img src="@img" width=400 style="float: left; margin: 0px 15px 15px 0px; border="2"></img>
        </div>
    </div>

""")
# Use number of models and regions to determine cell size
num_models = len(dd['model'].unique())
num_regions = len(dd['region'].unique())

cell_width = 1/num_models
cell_height = 1/num_regions

# set desired figure size
desired_width = 1300
desired_height = 10000

# calculate final width and height based on above parameters
adjusted_width = round(int(cell_width * desired_width), -1)
adjusted_height = round(int(cell_height * desired_height), -1)


reanalyses_plot = dd.hvplot.heatmap(y='region',
                       x='model',
                       C='peak',
                       hover_cols = ['img'],
                       tools = [hover],
                       height = adjusted_height,
                       width = adjusted_width,
                       colorbar=True,
                       clabel='peak day',
                       xaxis='top',
                       clim = (-180,180),
                       cmap='RdBu_r'
                       ).opts(xrotation=45, 
                              fontsize={
                                  'labels':10,
                                  'xticks': 10, 
                                  'yticks': 10
                                  }
                              )

reanalyses_plot = reanalyses_plot * hv.Labels(reanalyses_plot)
reanalyses_plot
# Out:
# :Overlay
#    .HeatMap.I :HeatMap   [model,region]   (peak,img)
#    .Labels.I  :Labels   [model,region]   (peak,img)

# %%
hvplot.save(reanalyses_plot , 'charts/reanalyses_plot02.html')

# %%
# creating portrait plot for Bias vs. ERA5 plot
# load data as array and create df
peak = np.loadtxt('data/output_diff_all_region_full.txt')
angle = peak.reshape(5,-1)

angle = np.where(angle < -182, angle+365, angle)
angle = np.where(angle >  182, angle-365, angle)

model_names = ["cmip5_CanESM2","cmip5_CCSM4","cmip5_CSIRO-Mk3-6-0","cmip5_NorESM1-M","cmip6_MRI-ESM2-0"]
region_names = ['California','SAmerica', 'Africa','NEurope','Australia','SAfrica', 'Baja', 'PAC NW', 'New Zealand', 'Alaska', 'UK', 'WEurope']

da = pd.DataFrame(data=angle, index=model_names, columns=region_names)

dd = da.stack()
dd = dd.reset_index()
dd = dd.rename(columns={"level_0": "model", "level_1": "region", 0 :"peak"})

img_path = 'https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/'
img_links = []

for i, model in enumerate(model_names):
    for j, region in enumerate(region_names):
        filename = img_path+'fig_'+str(i)+"_"+str(j)+'.png'
        img_links.append(filename)

dd['img'] = img_links
dd
# Out:
#                   model       region   peak  \
# 0         cmip5_CanESM2   California   -6.0
# 1         cmip5_CanESM2     SAmerica   20.0
# 2         cmip5_CanESM2       Africa -148.0
# 3         cmip5_CanESM2      NEurope   -3.0
# 4         cmip5_CanESM2    Australia  -16.0
# 5         cmip5_CanESM2      SAfrica  -81.0
# 6         cmip5_CanESM2         Baja   44.0
# 7         cmip5_CanESM2       PAC NW   -5.0
# 8         cmip5_CanESM2  New Zealand    8.0
# 9         cmip5_CanESM2       Alaska  -39.0
# 10        cmip5_CanESM2           UK    6.0
# 11        cmip5_CanESM2      WEurope   -4.0
# 12          cmip5_CCSM4   California -137.0
# 13          cmip5_CCSM4     SAmerica    3.0
# 14          cmip5_CCSM4       Africa    1.0
# 15          cmip5_CCSM4      NEurope  -81.0
# 16          cmip5_CCSM4    Australia   52.0
# 17          cmip5_CCSM4      SAfrica   -3.0
# 18          cmip5_CCSM4         Baja  -10.0
# 19          cmip5_CCSM4       PAC NW  -24.0
# 20          cmip5_CCSM4  New Zealand   17.0
# 21          cmip5_CCSM4       Alaska   45.0
# 22          cmip5_CCSM4           UK  -76.0
# 23          cmip5_CCSM4      WEurope  -24.0
# 24  cmip5_CSIRO-Mk3-6-0   California   12.0
# 25  cmip5_CSIRO-Mk3-6-0     SAmerica  -10.0
# 26  cmip5_CSIRO-Mk3-6-0       Africa   19.0
# 27  cmip5_CSIRO-Mk3-6-0      NEurope   -3.0
# 28  cmip5_CSIRO-Mk3-6-0    Australia  -13.0
# 29  cmip5_CSIRO-Mk3-6-0      SAfrica   -4.0
# 30  cmip5_CSIRO-Mk3-6-0         Baja   10.0
# 31  cmip5_CSIRO-Mk3-6-0       PAC NW   31.0
# 32  cmip5_CSIRO-Mk3-6-0  New Zealand -121.0
# 33  cmip5_CSIRO-Mk3-6-0       Alaska    4.0
# 34  cmip5_CSIRO-Mk3-6-0           UK    3.0
# 35  cmip5_CSIRO-Mk3-6-0      WEurope  -52.0
# 36      cmip5_NorESM1-M   California   57.0
# 37      cmip5_NorESM1-M     SAmerica    4.0
# 38      cmip5_NorESM1-M       Africa  -12.0
# 39      cmip5_NorESM1-M      NEurope    2.0
# 40      cmip5_NorESM1-M    Australia   11.0
# 41      cmip5_NorESM1-M      SAfrica   37.0
# 42      cmip5_NorESM1-M         Baja  177.0
# 43      cmip5_NorESM1-M       PAC NW   24.0
# 44      cmip5_NorESM1-M  New Zealand   -7.0
# 45      cmip5_NorESM1-M       Alaska   -5.0
# 46      cmip5_NorESM1-M           UK   38.0
# 47      cmip5_NorESM1-M      WEurope   -6.0
# 48     cmip6_MRI-ESM2-0   California   -6.0
# 49     cmip6_MRI-ESM2-0     SAmerica  -19.0
# 50     cmip6_MRI-ESM2-0       Africa   19.0
# 51     cmip6_MRI-ESM2-0      NEurope   59.0
# 52     cmip6_MRI-ESM2-0    Australia   16.0
# 53     cmip6_MRI-ESM2-0      SAfrica   51.0
# 54     cmip6_MRI-ESM2-0         Baja  -20.0
# 55     cmip6_MRI-ESM2-0       PAC NW   44.0
# 56     cmip6_MRI-ESM2-0  New Zealand   25.0
# 57     cmip6_MRI-ESM2-0       Alaska   57.0
# 58     cmip6_MRI-ESM2-0           UK   28.0
# 59     cmip6_MRI-ESM2-0      WEurope   10.0
#
#                                                                                           img
# 0    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_0.png
# 1    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_1.png
# 2    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_2.png
# 3    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_3.png
# 4    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_4.png
# 5    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_5.png
# 6    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_6.png
# 7    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_7.png
# 8    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_8.png
# 9    https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_9.png
# 10  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_10.png
# 11  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_0_11.png
# 12   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_0.png
# 13   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_1.png
# 14   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_2.png
# 15   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_3.png
# 16   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_4.png
# 17   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_5.png
# 18   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_6.png
# 19   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_7.png
# 20   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_8.png
# 21   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_9.png
# 22  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_10.png
# 23  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_1_11.png
# 24   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_0.png
# 25   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_1.png
# 26   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_2.png
# 27   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_3.png
# 28   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_4.png
# 29   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_5.png
# 30   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_6.png
# 31   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_7.png
# 32   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_8.png
# 33   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_9.png
# 34  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_10.png
# 35  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_2_11.png
# 36   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_0.png
# 37   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_1.png
# 38   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_2.png
# 39   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_3.png
# 40   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_4.png
# 41   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_5.png
# 42   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_6.png
# 43   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_7.png
# 44   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_8.png
# 45   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_9.png
# 46  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_10.png
# 47  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_3_11.png
# 48   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_0.png
# 49   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_1.png
# 50   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_2.png
# 51   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_3.png
# 52   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_4.png
# 53   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_5.png
# 54   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_6.png
# 55   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_7.png
# 56   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_8.png
# 57   https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_9.png
# 58  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_10.png
# 59  https://raw.githubusercontent.com/kristinchang3/peak_season_cmec/main/images/fig_4_11.png

# %%
# html for custom hover tool
hover = HoverTool(tooltips="""
    <div>
        <div>
            <img src="@img" width=400 style="float: left; margin: 0px 15px 15px 0px; border="2"></img>
        </div>
    </div>

""")

# Use number of models and regions to determine cell size
num_models = len(dd['model'].unique())
num_regions = len(dd['region'].unique())

cell_width = 1/num_models
cell_height = 1/num_regions

# set desired figure size
desired_width = 6000
desired_height = 6000

# calculate final width and height based on above parameters
adjusted_width = round(int(cell_width * desired_width), -1)
adjusted_height = round(int(cell_height * desired_height), -1)

bias_vs_era5 = dd.hvplot.heatmap(y='model',
                       x='region',
                       C='peak',
                       hover_cols = ['img'],
                       tools = [hover],
                       height = adjusted_height,
                       width=adjusted_width,
                       colorbar=True,
                       clabel = 'peak day',
                       xaxis='top',
                       clim = (-180,180),
                       cmap='RdBu_r').opts(xrotation=45, fontsize={
                           'labels': 14,
                           'xticks': 14,
                           'yticks': 14
                       })
bias_vs_era5 = bias_vs_era5 * hv.Labels(bias_vs_era5)
bias_vs_era5
# Out:
# :Overlay
#    .HeatMap.I :HeatMap   [region,model]   (peak,img)
#    .Labels.I  :Labels   [region,model]   (peak,img)

# %%
# save portrait plot to charts folder as an html file
# change file name each time saving a new version
# update index.md file to match new html file name

hvplot.save(bias_vs_era5, 'charts/bias_vs_era5.html')

# push changes to github to see updates on live webpage
